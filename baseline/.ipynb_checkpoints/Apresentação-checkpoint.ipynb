# %% [markdown]
# # Apresentação Grupos de palavras gerados pelo Algoritmo

# %% [markdown]
# - Produtos considerados: GPS e TV
#
# - No final são apresentados 50 clusters

# %%
import pandas as pd
from preprocess.preprocess import *
from utils.utils import *
import ast

import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ## Cell-phones

# %% [markdown]
# #### Lendo Resultados

# %%
clusters_results = open('./resultados/Cell-phones/Cell-phones-K.txt', 'r')

list_clusters = []

for cluster in clusters_results:
    list_clusters.append(ast.literal_eval(cluster))

# %% [markdown]
# #### Lendo Fetures

# %%
documents_reviews = read_json('./database-process/Cell-phones/Cell-phones_documents_reviews.json')
explicit, implicit = extract_terms_tag('Cell-phones')
# Out:
# Extraindo Candidatos: 8000it [00:00, 43312.30it/s]

# %% [markdown]
# #### Extraindo resultados explicitos

# %%
explicit_feature_result = []

for features in list_clusters:
    for feature in features:
        if feature in explicit:
            explicit_feature_result.append(feature)

# %%
len(explicit_feature_result)
# Out:
# 783

# %% [markdown]
# #### Lendo Explicit Gold

# %%
explicit_gold = open('./database/gold_standard/explicit_features_Cell-phones.txt', 'r')
gold_explicit = []

for feature in explicit_gold:
    item = feature.split('\n')[0]
    item = item.replace('_', ' ')
    gold_explicit.append(item)

# %%
len(gold_explicit)
# Out:
# 419

# %% [markdown]
# #### Transformando Listas em Conjuntos

# %%
# Gold SET
gold_explicit = set(gold_explicit)

# %%
# Resultado SET
explicit_feature_result = set(explicit_feature_result)

# %%
len(gold_explicit), len(explicit_feature_result)
# Out:
# (419, 783)

# %% [markdown]
# ### Calculando Métrica para as features explicits

# %% [markdown]
# precision = Nagree / Nresult
#
# recall = Nagree / Ngold
#
# F-score = 2×precision×recall / precision+recall

# %%
n_agree_explicit = gold_explicit.intersection(explicit_feature_result)

# %%
precision = len(n_agree_explicit) / len(explicit_feature_result)

# %%
print(precision)
# Out:
# 0.20561941251596424

# %%
recall = len(n_agree_explicit)/len(gold_explicit)

# %%
print(recall)
# Out:
# 0.38424821002386633

# %%
f1 = (2 * precision * recall )/ precision + recall

# %%
print(f1)
# Out:
# 1.152744630071599

# %% [markdown]
# # Aspect Cluster
#
# # 2 *(a + b)/ n * (n-1)

# %%
file = open('./database/gold_standard/aspectCluster_Cell-phones.txt', 'r')
cluster_gold = {}
for line in file:
    aux = line.split('[')
    name_cluster = aux[0]
    features = aux[1].split(']')[0].split(',')
    cluster_gold[name_cluster] = set()
    for feature in features:
        ft = feature.split('_')
        for f in ft:
            cluster_gold[name_cluster].add(f)

# %%
cluster_result = {}

for idx, cl in enumerate(clusters):
    cluster_result[idx] = set()
    clus=ast.literal_eval(cl)
    
    for c in clus:
        cluster_result[idx].add(c)

# %%
len(cluster_result.keys())
a = 0
b = 0
n1 = 0
n2 = 0
rsult = 0
for key in cluster_gold.keys():
    for k in cluster_result.keys():
        inter = cluster_result[k].intersection(cluster_gold[key])
        union = cluster_result[k].union(cluster_gold[key])
        a = a + len(inter)
        b = b + (len(union) - len(inter))
        n1 = n1 + len(union)
        
        r = 2*(a+b)/len(union) * (len(union) - 1)
        rsult = rsult + r

# %%
rsult
# Out:
# 0

# %%
stp_words = stopwords.words('english')
stp_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
if '.' not in 'years.samsung':
    print(True)

# %%
explicit, implicit = extract_terms_tag('TV')
# Out:
# Extraindo Candidatos: 8000it [00:00, 28691.90it/s]

# %%
explicit
# Out:
# ["'d",
#  '0s',
#  '1000hd hdmi',
#  '1080i',
#  '1080p',
#  '1080p hdtv',
#  '1080p lcd hdtv',
#  '1080p samsung upconverter',
#  '1080p tv',
#  '1180i',
#  '12-6pm',
#  '120hz',
#  '120hz feature',
#  '120hz lcd hdtv',
#  '120hz lnt4671f',
#  '1280x768',
#  '1920x1080',
#  '19inch pc',
#  '1s',
#  '1st samsung and know am looking',
#  '226bw',
#  '2405fpw',
#  '2d',
#  '2d-3d',
#  '2k7',
#  '2m2c',
#  '2months',
#  '2nd',
#  '2pm',
#  '2x4',
#  '30-days',
#  '32-inch lcd',
#  '32hl67u',
#  '32hl67u description',
#  '3d',
#  '3d bd player',
#  '3d blu ray',
#  '3d blue ray',
#  '3d content',
#  '3d effect',
#  '3d effects',
#  '3d experience',
#  '3d hdtv',
#  '3d hdtvs',
#  '3d objects',
#  '3d picture',
#  '3d quality',
#  '3d tv',
#  '3rd',
#  '3xhdmi',
#  '40inch',
#  '40ux600u',
#  '40v3000',
#  '4661f',
#  '480p mode',
#  '4am',
#  '4k',
#  '4k content',
#  '4k tv',
#  '5015d',
#  '55in',
#  '5687w',
#  '5pm',
#  '5th',
#  '6150f',
#  '61dlp',
#  '700u',
#  '720p',
#  '720p plasma',
#  '87s',
#  '89s model',
#  'a-3 hd-dvd player',
#  'a-ok',
#  'abc hd',
#  'abc7',
#  'ability',
#  'about',
#  'ac socket',
#  'accent light',
#  'acceptance',
#  'accesories',
#  'access',
#  'accessories',
#  'accessory',
#  'account',
#  'accounts',
#  'acquisition',
#  'act',
#  'action',
#  'action lawsuit',
#  'action scenes',
#  'action sequences',
#  'action video',
#  'activities',
#  'adaptor',
#  'adaptors',
#  'addition',
#  'adjusting',
#  'adjustment',
#  'adjustments',
#  'adults',
#  'advantage',
#  'advantages',
#  'advice',
#  'aesthetics',
#  'affordability',
#  'afternoon',
#  'afterthought',
#  'again',
#  'age technology',
#  'agency',
#  'ages',
#  'agreements',
#  'ahead',
#  'air',
#  'air broadcasts',
#  'air channels a-ok',
#  'air tuner',
#  'airtrack',
#  'alarm',
#  'all',
#  'allowance',
#  'allshare',
#  'along',
#  'alot',
#  'already',
#  'already bought this',
#  'also',
#  'also have plasma but this',
#  'always',
#  'am',
#  'am looking',
#  'amazaon',
#  'amazing',
#  'amazon',
#  'amazon experience',
#  'amazon instant video',
#  'amazon purchase',
#  'amazon service',
#  'amazon today',
#  'american english',
#  'american express',
#  'amex',
#  'amount',
#  'amp',
#  'amplifiers',
#  'analog',
#  'analog cable',
#  'analog channels',
#  'analog component cables',
#  'analog pc connection',
#  'analog signal',
#  'analog station',
#  'analog tv',
#  'analog tv tuner source',
#  'and',
#  'and know am looking',
#  'and operation',
#  'android',
#  'angeles',
#  'angle',
#  'angle distortion',
#  'angles',
#  'announcers',
#  'annoyance',
#  'anonadado',
#  'anouther',
#  'answer',
#  'answers',
#  'antenna',
#  'antenna channels',
#  'antenna input',
#  'antenna tuner',
#  'antennae',
#  'antennas',
#  'anticipation',
#  'anwhere',
#  'any samsung',
#  'anybody',
#  'anynet feature',
#  'anynet hdmi',
#  'anyone',
#  'anyone thinking',
#  'anything',
#  'anything samsung',
#  'anyways',
#  'apartment',
#  'apocalypto',
#  'apocolypto',
#  'app',
#  'appearance',
#  'apple',
#  'apple tv',
#  'appletv',
#  'appletv box',
#  'appliances',
#  'application',
#  'applications',
#  'appointment',
#  'apps',
#  'aquos',
#  'area',
#  'area cable company',
#  'area code',
#  'areas',
#  'around',
#  'arrangements',
#  'array',
#  'arrival date',
#  'art',
#  'articles',
#  'artifacts',
#  'artifcating',
#  'aspect',
#  'aspect ratio tv',
#  'aspects',
#  'assassin',
#  'assembly',
#  'assistant',
#  'assurance',
#  'atmosphere',
#  'attack',
#  'attention',
#  'attitude',
#  'audacity',
#  'audio',
#  'audio amplifiers',
#  'audio channel',
#  'audio format option',
#  'audio source',
#  'audiophile',
#  'august',
#  'auto',
#  'auto dimming issue',
#  'auto parts stores',
#  'auto tuning',
#  'auto volume',
#  'auto-tune function',
#  'av',
#  'av input',
#  'av receiver',
#  'average',
#  'avia',
#  'avs forum',
#  'avsforum site',
#  'award shows',
#  'away from samsung',
#  'awe',
#  'awesome',
#  'awsome',
#  'b&m',
#  'b4',
#  'b8500',
#  'baby',
#  'back',
#  'background',
#  'background atmosphere',
#  'background music',
#  'backlight',
#  'backlight brighter',
#  'backlight pixels',
#  'bad',
#  'balance',
#  'ball effect',
#  'band wagon',
#  'banding',
#  'banding issues',
#  'bang',
#  'bank',
#  'bank account',
#  'bar',
#  'bar code lines',
#  'bar volume',
#  'bargain',
#  'bargain guy',
#  'bargain hunter',
#  'bars',
#  'base',
#  'baseball',
#  'basement',
#  'basement corner',
#  'basis',
#  'basketball',
#  'bass',
#  'battery',
#  'battlefield',
#  'bay',
#  'bb',
#  'bball game',
#  'bd player',
#  'bd-f5100',
#  'beast',
#  'beat by',
#  'beautiful picture',
#  'becuase',
#  'bed room',
#  'bed room tv',
#  'bedroom',
#  'bedroom apartment',
#  'bedroom set',
#  'bedroom size tv',
#  'bedroom television',
#  'bedroom tv',
#  'bedrooms',
#  'bedtime',
#  'before',
#  'beginning',
#  'bells',
#  'benefit',
#  'benefits',
#  'bergman',
#  'best',
#  'best bang',
#  'best blacks',
#  'best choice',
#  'best clarity',
#  'best hdtv',
#  'best picture',
#  'best picture quality',
#  'best price',
#  'best purchase',
#  'best selection possible after careful review',
#  'best tv',
#  'best tv ever',
#  'best value',
#  'bestbuy',
#  'bet',
#  'better',
#  'better deal on',
#  'better tv',
#  'betweeen',
#  'beutiful picture',
#  'beware',
#  'bezel',
#  'bezel black',
#  'bezels',
#  'big',
#  'big samsung',
#  'biggie',
#  'bingo',
#  'bishop',
#  'bit',
#  'bit problem',
#  'bit video processing',
#  'bits',
#  'black',
#  'black contrast',
#  'black friday',
#  'black level',
#  'black monday',
#  'blacklight',
#  'blacks',
#  'blank',
#  'ble-ray',
#  'blemish',
#  'blimeshes',
#  'blinds',
#  'blows',
#  'blu ray',
#  'blu-ray',
#  'blu-ray player',
#  'blu-rays',
#  'blue',
#  'blue ray',
#  'blueray',
#  'blues',
#  'bluetooth',
#  'blur',
#  'bluray',
#  'bluray players',
#  'board',
#  'board failure',
#  'boards',
#  'bond',
#  'bonus',
#  'book',
#  'borat',
#  'border',
#  'bose',
#  'bose lifestyle',
#  'bose surround',
#  'bose system',
#  'boston',
#  'bottom',
#  'bottom line',
#  'bought',
#  'bought this',
#  'bowl',
#  'bowl games',
#  'box',
#  'box settings',
#  'box setup',
#  'box stores',
#  'box system',
#  'box tv settings',
#  'box-for',
#  'boxes',
#  'boy',
#  'bracket',
#  'brainer',
#  'brand',
#  'brand hdtv',
#  'brand manfacturer',
#  'brand name cables',
#  'brand names',
#  'brands',
#  'brandsand',
#  'bravia',
#  'bravia kdl400v3000',
#  'bravia xbr',
#  'bravias',
#  'bravo samsung',
#  'break',
#  'breakdown',
#  'breaker',
#  'breaks',
#  'breath',
#  'breath taking',
#  'breeze',
#  'brick',
#  'brighness display quality',
#  'brighter',
#  'brighter look',
#  'brighthouse',
#  'brightness',
#  'brightness characteristics',
#  'brightness feature',
#  'brits',
#  'broadcast',
#  'broadcasting',
#  'broadcasts',
#  'broken',
#  'brother',
#  'browser',
#  'btw',
#  'buck',
#  'buck type stuff',
#  'bucks',
#  'buddy',
#  'budget',
#  'buff',
#  'buffering capacity',
#  'building',
#  'bulb',
#  'bulb replacement',
#  'bulk',
#  'bumps',
#  'bunch',
#  'bureaucracy',
#  'burn-in',
#  'burn-in problems',
#  'burning',
#  'bush',
#  'business',
#  'business days',
#  'business functions',
#  'buster deal',
#  'but',
#  'but seeing this samsung',
#  'but this',
#  'butt',
#  'button',
#  'button placement',
#  'buttons',
#  'buy',
#  'buy from this company again',
#  'buy it',
#  'buy online',
#  'buy this',
#  'buy this tv',
#  'buyer',
#  'buyers',
#  'buying',
#  'buying experiences',
#  'buying guide',
#  'buying my 1st samsung and know am looking',
#  'buying online',
#  'buyingdigital video',
#  'buzz',
#  'by',
#  'ca',
#  'cabinets',
#  'cable',
#  'cable box',
#  'cable box setup',
#  'cable cards',
#  'cable channels',
#  'cable co',
#  'cable company',
#  'cable connection',
#  'cable connections',
#  'cable connnections',
#  'cable dvr signal',
#  'cable guy',
#  'cable hd',
#  'cable hdmi box',
#  'cable input',
#  'cable person',
#  'cable ports',
#  'cable programming',
#  'cable provider',
#  'cable providers box',
#  'cable service',
#  'cable signal',
#  'cable tv',
#  'cable tv dvr',
#  'cable wire',
#  'cable-dvr box-for',
#  'cables',
#  'cain',
#  'calibration',
#  'calibration dvd',
#  'calibration website suggestions',
#  'call',
#  'calls',
#  'camera',
#  'camera pans',
#  'cameras',
#  'canon',
#  'cant',
#  'capabilities',
#  'capability',
#  'capacitor',
#  'capacitor issue',
#  'capacitor replacement',
#  'capacitors',
#  'capacity',
#  'captions',
#  'car',
#  'card',
#  'card company',
#  'card member agreements',
#  'card reader',
#  'cards',
#  'care',
#  'careful',
#  'careful review',
#  'carpet',
#  'carrier',
#  'cars',
#  'case',
#  'cases',
#  'cash',
#  'category',
#  'cathode ray tubes',
#  'cause',
#  'caution',
#  'cbs',
#  'cbs hd',
#  'cc',
#  'ce dimming',
#  'ceiling light',
#  'ceiling windows',
#  'cell number',
#  'cell phone',
#  'center',
#  'center channel',
#  'center half',
#  'center speaker',
#  'centerpiece',
#  'centers',
#  'cents',
#  'certificate',
#  'ceva',
#  'ceva logistics',
#  'chair',
#  'challenge',
#  'champion',
#  'chance',
#  'chances',
#  'change',
#  'changes',
#  'channel',
#  'channel apps',
#  'channel guide',
#  'channel manager',
#  'channel numbers',
#  'channel program information',
#  'channel selection use rca code',
#  'channels',
#  'characteristics',
#  'charge',
#  'charges',
#  'charm',
#  'charter cable',
#  'chase',
#  'chase bank',
#  'chase scene',
#  'chassis',
#  'chat',
#  'check',
#  'chest',
#  'chicago',
#  'children',
#  'choice',
#  'choices',
#  'chores',
#  'chorus',
#  'christmas',
#  'cincinnati',
#  'cinema series',
#  'cinema set',
#  'circuit',
#  'circuit board',
#  'circuit city',
#  'circuit city salesperson',
#  'circumstances',
#  'circut city',
#  'citi',
#  'city',
#  'city morning',
#  'city salesperson',
#  'claim',
#  'clairty',
#  'clarification',
#  'clarity',
#  'class',
#  'class action lawsuit',
#  'cleaner',
#  'cleaning cloth',
#  'clear screen',
#  'clearly',
#  'clicker',
#  'clips',
#  'clones',
#  'close',
#  'close-up',
#  'closed',
#  'closeups',
#  'cloth',
#  'clothes',
#  'cloud controversy',
#  'cloud issue',
#  'cloud issues',
#  'clouding',
#  'clouds',
#  'club',
#  'cluster',
#  'cnet',
#  'co',
#  'coat',
#  'cod4',
#  'code',
#  'code lines',
#  'codes',
#  'coil',
#  'colbert report',
#  'collection',
#  'college',
#  'college student',
#  'color',
#  'color clarity',
#  'color pixel',
#  'color preferences',
#  'color quality',
#  'color saturation',
#  'color setting',
#  'color styles',
#  'color temperature',
#  'color temperature warmenhanced black level',
#  'color temperatures',
#  'color tweaking',
#  'color wheel',
#  'colorimeter',
#  'colors',
#  'com',
#  'comands',
#  'combination',
#  'combo',
#  'comcast',
#  'comcast hdtv',
#  'command center',
#  'command feature',
#  'commands',
#  'comment',
#  'comments',
#  'commission',
#  'communication',
#  'companies',
#  'company',
#  'company again',
#  'comparison',
#  'comparison shopping',
#  'comparisons',
#  'competition',
#  'competitior models',
#  'competitor',
#  'competitors',
#  'complaint',
#  'complaints',
#  'compliant',
#  'compliment',
#  'compliments',
#  'component',
#  'component cable',
#  'component cables',
#  'component input',
#  'component inputs',
#  'component receiver',
#  'component switching',
#  'component video cable',
#  'component video inputs',
#  'components',
#  'composite',
#  'compression technique',
#  'compromise',
#  'computer',
#  'computer knowledge',
#  'computer monitor',
#  'computer monitors',
#  'computer resolution',
#  'computer screen',
#  'computer speakers',
#  'computers',
#  'con',
#  'concept',
#  'concern',
#  'concerns',
#  'conclusion',
#  'condition',
#  'condition scratch',
#  'conditions',
#  'condo',
#  'confidence',
#  'configuration',
#  'confusion',
#  'congrats',
#  'congress',
#  'connection',
#  'connection options',
#  'connections',
#  'connectivity',
#  'connector',
#  'connectors',
#  'connnections',
#  'cons',
#  'consideration',
#  'console',
#  'construction',
#  'consumer',
#  'consumer electronics item',
#  'consumer magazine',
#  'consumer report',
#  'consumer reports',
#  'consumers',
#  'consumption',
#  'contact information',
#  'contender',
#  'content',
#  'contract',
#  'contract ratio',
#  'contrast',
#  'contrast ratio',
#  'contrast ratio-that',
#  'control',
#  'control codes',
#  'control functions',
#  'controls',
#  'controversy',
#  'conversations',
#  'conversion',
#  'converson',
#  'converter',
#  'converting',
#  'cool',
#  'cooling',
#  'cord',
#  'cords',
#  'core',
#  'corner',
#  'cost',
#  'costco',
#  'costs',
#  'cotsco',
#  'couch',
#  'could find better deal on',
#  'coumputer monitors',
#  'country freight trip',
#  'counts',
#  'couple',
#  'couple days',
#  'couple hours',
#  'couple models',
#  'couple months',
#  'couple weeks',
#  'coupon',
#  'couriers',
#  'course',
#  'court',
#  'courts',
#  'cover',
#  'coverage',
#  'cox',
#  'cpu',
#  'crack',
#  'crap',
#  'credit',
#  'credit card',
#  'credit card company',
#  'creed',
#  'crisp',
#  'criticism',
#  'cross-talk',
#  'crowd',
#  'crt',
#  'crt tv',
#  'crutchfield',
#  'crystal',
#  'cube',
#  'curve',
#  'custom',
#  'custom name input options',
#  'custom picture settings',
#  'custom settings',
#  'customer',
#  'customer center',
#  'customer experience',
#  'customer loyalty',
#  'customer reviews',
#  'customer service',
#  'customer service department',
#  'customer service guys',
#  'customer service representative',
#  'customer service reps',
#  'customer support',
#  'customers',
#  'customization',
#  'customization features',
#  'custtomer service',
#  'cut',
#  'cuts',
#  'cuz majority',
#  'cwl',
#  'cyber weekends',
#  'cycle',
#  'cycling',
#  'd8000',
#  'dad',
#  'daily show',
#  'dallas',
#  'damage',
#  'dark',
#  'data',
#  'date',
#  'date estimation',
#  'daughter',
#  'day',
#  'day gift',
#  'day light',
#  'day period',
#  'day return policy',
#  'day warranty',
#  'daylight',
#  'daylight viewing',
#  'days',
#  'deadline',
#  'deal',
#  'deal breaker',
#  'deal maker',
#  'deal on',
#  'dealbreaker',
#  'dealer reviews',
#  'dealers',
#  'deals',
#  'death',
#  'debit card',
#  'debugging',
#  'dec',
#  'dec27th',
#  'december',
#  'decision',
#  'decision points',
#  'decission',
#  'decline',
#  'decor',
#  'def',
#  'def broadcasts',
#  'def channels',
#  'def picture',
#  'def viewing',
#  'default',
#  'default picture settings',
#  'default profiles',
#  'default settings',
#  'default settings though-lots',
#  'defaults',
#  'defect',
#  'defects',
#  'definintion',
#  'definitely',
#  'definition',
#  'definition input',
#  'degree',
#  'degrees',
#  'delay',
#  'delight',
#  'deliveries',
#  'deliveries setup',
#  'deliverly',
#  'delivery',
#  'delivery appointment',
#  'delivery charges',
#  'delivery companies',
#  'delivery company',
#  'delivery date',
#  'delivery day',
#  'delivery estimate',
#  'delivery experience',
#  'delivery guy',
#  'delivery guys',
#  'delivery horror stories',
#  'delivery man',
#  'delivery people',
#  'delivery process',
#  'delivery quality',
#  'delivery service',
#  'delivery situation',
#  'delivery team',
#  'delivery time',
#  'delivery truck',
#  'delivery van',
#  'delivery window',
#  'deliveryof',
#  'dell',
#  'dell 2405fpw',
#  'demand',
#  'dement',
#  'demonstration',
#  'demostration',
#  'den',
#  'denver',
#  'department',
#  'depth',
#  'description',
#  'design',
#  'design defect',
#  'design flaw',
#  'design variations',
#  'designers',
#  'designs',
#  'desire',
#  'desk',
#  'detail',
#  'details',
#  'device',
#  'devices',
#  'dfw',
#  'diagnosis',
#  'dialing',
#  'diamond',
#  'dices',
#  'difference',
#  'differences',
#  'different model',
#  'differnce',
#  'difficulties',
#  'difficulty',
#  'dig',
#  'digicams',
#  'digital',
#  'digital cable',
#  'digital tv',
#  'digital video',
#  'digitization',
#  'dilemma',
#  'dilvery',
#  'dimensions',
#  'dimming',
#  'dimming issue',
#  'dimming ultimate',
#  'dinasour',
#  'direct-tv',
#  'direction',
#  'directions',
#  'directtv',
#  'directv',
#  'directv box',
#  'directv hd',
#  'dirt',
#  'disapointment',
#  'disappointment',
#  'disc',
#  'disc players',
#  'disclaimer',
#  'discoloration',
#  'discount',
#  'discount coupon',
#  'discovery hd',
#  'discs',
#  'discussion',
#  'discussion thread',
#  'dish',
#  'dish hd',
#  'dish hd output',
#  'dish network',
#  'dish network guy',
#  'dish network hd',
#  'dish network international',
#  'dish networksatellite',
#  'dishwasher',
#  ...]

# %%
2102 - 1690
# Out:
# 412
